# %% [markdown]
# ### Seaborn

# %%
#Importing the libraries

# %%
import pandas as ps
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=ps.read_csv("Placement_Data_Full_Class.csv")
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1.0      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2.0      M  79.33  Central  78.33   Others   Science     77.48
# 2      3.0      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4.0      M  56.00  Central  52.00  Central   Science     52.00
# 4      5.0      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 212  211.0      M  80.60   Others  82.00   Others  Commerce     77.60
# 213  212.0      M  58.00   Others  60.00   Others   Science     72.00
# 214  213.0      M  67.00   Others  67.00   Others  Commerce     73.00
# 215  214.0      F  74.00   Others  66.00   Others  Commerce     58.00
# 216  215.0      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
#this is a raw data we have to do preprocessing method with easy method using some libraries

# %%
#Number of columns and rows
print("Number of Rows :",dataset.shape[0])
print("Number of Columns :",dataset.shape[1])
# Out:
# Number of Rows : 217
# Number of Columns : 15

# %%
dataset.shape
# Out:
# (217, 15)

# %%
#load the user defined function which is already created in Univariate analysis
from Data_analysis import Univariate_class
obj=Univariate_class()

# %%
#Split the Quantative and Qualtatiive column names
Qual,Quan=obj.Quan_Qual(dataset)

# %%
Quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
#Descriptive Porcess
data_set=obj.univariate(dataset,Quan)
data_set
# Out:
#               sl_no       ssc_p       hsc_p   degree_p     etest_p      mba_p  \
# Mean          108.0   67.303395   66.333163  66.370186   72.100558  62.278186
# Median        108.0        67.0        65.0       66.0        71.0       62.0
# Mode            1.0        62.0        63.0       65.0        60.0       56.7
# Q1:25%         54.5        60.6        60.9       61.0        60.0     57.945
# Q2:50%        108.0        67.0        65.0       66.0        71.0       62.0
# Q3:75%        161.5        75.7        73.0       72.0        83.5     66.255
# Q4:100%       215.0        89.4        97.7       91.0        98.0      77.89
# IQR           107.0        15.1        12.1       11.0        23.5       8.31
# 1.5rule       160.5       22.65       18.15       16.5       35.25     12.465
# Lesser       -106.0       37.95       42.75       44.5       24.75      45.48
# Greater       322.0       98.35       91.15       88.5      118.75      78.72
# ...

# %%
#check the outlier
lesser, greater=obj.check_outliers(Quan,data_set)
print(lesser,greater)
# Out:
# ['hsc_p'] ['hsc_p', 'degree_p', 'salary']

# %%
# If outlier present run this, to replace the value
Changed_data=obj.change_outlier(data_set)
Changed_data
# Out:
#               sl_no       ssc_p      hsc_p   degree_p     etest_p      mba_p  \
# Mean          108.0   67.303395  66.333163  66.370186   72.100558  62.278186
# Median        108.0        67.0       65.0       66.0        71.0       62.0
# Mode            1.0        62.0       63.0       65.0        60.0       56.7
# Q1:25%         54.5        60.6       60.9       61.0        60.0     57.945
# Q2:50%        108.0        67.0       65.0       66.0        71.0       62.0
# Q3:75%        161.5        75.7       73.0       72.0        83.5     66.255
# Q4:100%       215.0        89.4      91.15       88.5        98.0      77.89
# IQR           107.0        15.1      42.75       11.0        23.5       8.31
# 1.5rule       160.5       22.65      42.75       16.5       35.25     12.465
# Lesser       -106.0       37.95      42.75       44.5       24.75      45.48
# Greater       322.0       98.35      91.15       88.5      118.75      78.72
# ...

# %%
#re-check the outlier
lesser, greater=obj.check_outliers(Quan,data_set)
print(lesser,greater)
# Out:
# [] []

# %% [markdown]
# ### Univariate analysis

# %%
import seaborn as sb

# %%
sb.distplot(dataset["ssc_p"],hist=True,kde=True,kde_kws={'color':'red'})
# Out:
# C:\Users\smani\AppData\Local\Temp\ipykernel_13508\3221579708.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(dataset["ssc_p"],hist=True,kde=True,kde_kws={'color':'red'})
# <Axes: xlabel='ssc_p', ylabel='Density'>

# %% [markdown]
# ### Bivariate analysis: Distribution plot

# %%
sb.jointplot(x="ssc_p",y="salary",data=dataset)
plt.show()
#It will show the Scatter plot and Histogram for X and Y.

# %%
sb.jointplot(x='ssc_p',y='salary',data=dataset,kind='hex')
#Color represents the number of data points within each bin

# %%
sb.jointplot(x='ssc_p',y='salary',data=dataset,kind='kde')
#we can see the more no of curves in max no of repetition in max curve

# %% [markdown]
# ### Pairplot

# %%
sb.pairplot(dataset,hue="gender",diag_kind="kde",kind="scatter",palette="husl")
#We give hue="gender", so it was compare the gender in every numerical columns.

# %% [markdown]
# ### Categorical plot

# %%
sb.stripplot(x="gender",y="ssc_p",data=dataset,jitter=True)
#we can see how data was splits
# Out:
# <Axes: xlabel='gender', ylabel='ssc_p'>

# %%
sb.swarmplot(x="gender",y="ssc_p",data=dataset) 
#It will avoid overlap
# Out:
# <Axes: xlabel='gender', ylabel='ssc_p'>

# %% [markdown]
# # Distribution Observation

# %%
sb.violinplot(x="gender",y="ssc_p",data=dataset,palette="pastel")
# Out:
# C:\Users\smani\AppData\Local\Temp\ipykernel_13508\2835760123.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.violinplot(x="gender",y="ssc_p",data=dataset,palette="pastel")
# <Axes: xlabel='gender', ylabel='ssc_p'>

# %%
sb.violinplot(x="ssc_b",y="ssc_p",data=dataset,hue="gender")
#It will show density plot with boxplot
# Out:
# <Axes: xlabel='ssc_b', ylabel='ssc_p'>

# %%
sb.boxplot(x="ssc_b",y="ssc_p",data=dataset,hue="gender")
#It will show the percentile (IQR), we can see the IQR in this graph.
# Out:
# <Axes: xlabel='ssc_b', ylabel='ssc_p'>

# %%
sb.boxplot(x="hsc_b",y="hsc_p",data=dataset,hue="gender")
# Out:
# <Axes: xlabel='hsc_b', ylabel='hsc_p'>

# %%
#Explanation of this box plot,
#In this Others Male, Female have both Lesser and Greater outlier, Central Male and Female had Lesser outlier
#In others Male max score was lesser than Female. the average score male have higher than female.
#In Central Male max score was lesser than Female. the average score male have lesser than female

# %%
#Bar plot

# %%
sb.barplot(x="ssc_b",y="ssc_p",data=dataset,hue="gender")
# Out:
# <Axes: xlabel='ssc_b', ylabel='ssc_p'>

# %%
sb.countplot(x="ssc_b",data=dataset,hue="gender")
#it will show the count of the data in graph
# Out:
# <Axes: xlabel='ssc_b', ylabel='count'>

# %%
sb.pointplot(x="ssc_p", y="ssc_b",data=dataset, hue="gender")
#To find the mean value, compared with categorical data with numerical data.
# Out:
# <Axes: xlabel='ssc_p', ylabel='ssc_b'>

# %%
sb.boxplot(data=dataset, orient="h")
# Out:
# <Axes: >

# %%
sb.regplot(x="ssc_p",y="hsc_p",data=dataset)
# Out:
# <Axes: xlabel='ssc_p', ylabel='hsc_p'>

# %%
sb.lmplot(x="ssc_p",y="hsc_p",data=dataset)
